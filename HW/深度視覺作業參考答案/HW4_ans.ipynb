# %% [markdown]
# # Neural Network for CIFAR10 Classification
# In this assignment, we will implement a two-layer fully-connected neural network for CIFAR10 classification.

# %% [markdown]
# ## Data Preparation and Visualization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/HW4/')

# %%
# You may change `MODEL_DIR` to a existing local directory if you are not using Colab
MODEL_DIR = '/content/'
MODEL_PATH = MODEL_DIR + 'model.pt' if MODEL_DIR.endswith('/') else MODEL_DIR + '/model.pt'

# %%
from _utils import load_data, Dataset, Dataloader, FCL_Tests, ReLU_Tests, SCE_Tests, plot_curves, plot_result
import numpy as np
import matplotlib.pyplot as plt
import random
import torch

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
  print(f'Using torch {torch.__version__}, device = {torch.cuda.get_device_name(0)}')
else:
  DEVICE = 'cpu'
  print(f'Using torch {torch.__version__}, device = cpu')
# Out:
# Using torch 1.13.1+cu116, device = Tesla T4

# %%
images, labels, classes = load_data()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10/

# %%
print(f'Data type of images: {images.dtype} (value range: [{images.min()}, {images.max()}])')
print(f'Shape of images: {images.shape}')
print(f'Shape of labels: {labels.shape}')
print(f'Number of classes: {len(classes)}')
print(f'Classes: {classes}')
# Out:
# Data type of images: uint8 (value range: [0, 255])
# Shape of images: (50000, 32, 32, 3)
# Shape of labels: (50000,)
# Number of classes: 10
# Classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Display samples of each class
plt.rcParams['figure.figsize'] = (16, 16)
num_classes = len(classes)
num_example = 10
for label, class_name in enumerate(classes):
  idxs = np.flatnonzero(labels == label)
  idxs = np.random.choice(idxs, num_example, replace=False)
  for i, idx in enumerate(idxs):
    plt_idx = i * num_classes + label + 1
    plt.subplot(num_example, num_classes, plt_idx)
    plt.imshow(images[idx]); plt.axis('off')
    if i == 0:
      plt.title(class_name)
plt.show()

# %%
# Data splitting with numpy array slicing
num_data = images.shape[0]
split_ratio = {'train': 0.6, 'valid': 0.2, 'test': 0.2}
num_valid_data = round(num_data * split_ratio['valid'])
num_test_data = round(num_data * split_ratio['test'])
num_train_data = num_data - (num_valid_data + num_test_data)

start_idx = 0
train_dataset = Dataset(images[start_idx:start_idx+num_train_data], labels[start_idx:start_idx+num_train_data])
start_idx += num_train_data

valid_dataset = Dataset(images[start_idx:start_idx+num_valid_data], labels[start_idx:start_idx+num_valid_data])
start_idx += num_valid_data

test_dataset = Dataset(images[start_idx:start_idx+num_test_data], labels[start_idx:start_idx+num_test_data])

print(f'Number of training data: {len(train_dataset)}')
print(f'Number of validation data: {len(valid_dataset)}')
print(f'Number of test data: {len(test_dataset)}')
# Out:
# Number of training data: 30000
# Number of validation data: 10000
# Number of test data: 10000

# %% [markdown]
# ## Layer Definition
# The architecture of our two-layer fully-connected neural network is like:
#
# Input $\rightarrow$ Fully-Connected Layer1 $\rightarrow$ ReLU  $\rightarrow$ Fully-Connected Layer2 $\rightarrow$ Softmax
#
# The learnable parameters are weights and bias of the two fully-connected layers. Let's name and clarify the parameters and their shapes:
#
# 1. Input data: $\mathbf{x}$, shape: ${N\times D}$
# 2. Weights of first fully-connected layer: $\mathbf{w_1}$, shape: ${D\times H}$
# 3. Bias of first fully-connected layer: $\mathbf{b_1}$, shape: ${H}$
# 4. Weights of second fully-connected layer: $\mathbf{w_2}$, shape: ${H\times C}$
# 5. Bias of second fully-connected layer: $\mathbf{b_2}$, shape: ${C}$
# 6. Output of the network: $\mathbf{S}$, shape: ${N\times C}$
#
# And then we can simply express the function of our network by:
# $$\mathbf{S} = \mathbf{w_2} * ReLU(\mathbf{w_1} * \mathbf{x} + \mathbf{b_1}) + \mathbf{b_2}$$
#
# Since the two fully-connected layers do the same job, that is, multiply weights with input and then plus bias, we define a class called FullyConnectedLayer to implement a single fully-connected layer.

# %%
class FullyConnectedLayer(object):
  def __init__(self, device='cpu'):
    self.dv = device
  def forward(self, x, w, b):
    N, D = x.shape
    Dw, F = w.shape
    assert Dw == D, f'Wrong shape of weights, expected ({D},{F}) but got ({Dw},{F})'
    Fb = b.shape[0]
    assert Fb == F, f'Wrong shape of bias, expected ({F},) but got ({Fb},)'
    out = torch.zeros((N, F)).to(self.dv)
    ####################
    # TODO:
    # 1. Implement fully connected layer with `w` * `x` + `b` and store the result in variable `out`
    ####################
    # -----START OF YOUR CODE-----
    out = x.mm(w) + b
    # ------END OF YOUR CODE------
    self.cache = (x, w, b, out)
    return out
  def backward(self, backprop):
    N, F = backprop.shape
    dw = None
    db = None
    ####################
    # TODO:
    # 1. Derive the gradient of bias, i.e., d(out)/d(b)
    # 2. Multiply d(out)/d(b) with `backprop` due to chain rule, and then store the AVERAGED result in variable `db`
    # 3. Then, derive the gradient of weights, i.e., d(out)/d(w)
    # 4. Multiply d(out)/d(w) with `backprop` due to chain rule, and then store the AVERAGED result in variable `dw`
    # HINT: Shapes of `db` and `dw` should be (F,) and (D, F) respectively
    ####################
    # -----START OF YOUR CODE-----
    x, _, _, _ = self.cache
    db = backprop.mean(0)
    dw = x.T.mm(backprop) / N
    # ------END OF YOUR CODE------
    return dw, db

# %%
layer = FullyConnectedLayer()
FCL_Tests(layer)
# Out:
# Results of fully connected layer forward and backward tests: All passed.

# %% [markdown]
# ReLU (Rectified Linear Unit) is the currently most used non-linearity (or called activation function) in neural networks. Its formula as following:
# $$ReLU(t) = max(0, t)$$
#
# Since ReLU only allows positive values to be passed forward, any negative values of the input will not be able to propagate gradients during backpropagation.

# %%
class ReLU(object):
  def __init__(self):
    pass
  def forward(self, t):
    out = t.clone()
    ####################
    # TODO:
    # 1. Implement ReLU on `t` and store in variable `out`
    ####################
    # -----START OF YOUR CODE-----
    out[t < 0] = 0
    # ------END OF YOUR CODE------
    self.cache = (t, out)
    return out
  def backward(self, backprop):
    dt = torch.zeros_like(backprop)
    ####################
    # TODO:
    # 1. Derive d(out)/d(t)
    # 2. Multiply d(out)/d(t) with `backprop` due to chain rule, and then store the result in variable `dt`
    ####################
    # -----START OF YOUR CODE-----
    t, _ = self.cache
    mask = t.clone()
    mask[t < 0] = 0
    mask[t > 0] = 1
    dt = backprop * mask
    # ------END OF YOUR CODE------
    return dt

# %%
layer = ReLU()
ReLU_Tests(layer)
# Out:
# Results of ReLU function tests: All passed.

# %% [markdown]
# Softmax is used to convert a vector of real numbers into a probability distribution over classes. It can be expressed mathematically as:
# $$softmax(\mathbf{S}_i)=\mathbf{p}_i=\frac{exp(\mathbf{S}_i)}{\sum_{j=1}^\mathbf{C}exp(\mathbf{S}_j)}$$
# And the cross-entropy loss, on the other hand, is a measure of the difference between the predicted probability distribution and the true probability distribution of the labels. Let $\mathbf{y}$ be **one-hot encoded** ground-truth label, that is, its shape would be the same with output of the network. Cross-entropy loss formula is defined as:
# $$CE = -\sum\mathbf{y}_i * log(\mathbf{p}_i)$$

# %%
class Softmax_CrossEntropy(object):
  def __init__(self):
    pass
  def forward(self, y, net_out):
    N, F = net_out.shape
    prob = torch.zeros_like(net_out)
    ####################
    # TODO:
    # 1. Implement Softmax and store the result in variable `prob`
    # HINT: Shape of `prob` should be (N, F)
    ####################
    # -----START OF YOUR CODE-----
    prob = net_out - torch.max(net_out, axis=1, keepdims=True).values
    prob = torch.exp(prob)
    prob /= torch.sum(prob, axis=1, keepdims=True)
    # ------END OF YOUR CODE------
    self.cache = (y, prob)
    pred_y = prob.argmax(dim=1)
    
    y_one_hot = torch.zeros_like(net_out)
    y_one_hot[np.arange(N), y] = 1
    loss = torch.zeros(1)
    ####################
    # TODO:
    # 1. Implement cross-entropy loss and store the result in variable `loss`
    ####################
    # -----START OF YOUR CODE-----
    loss = torch.sum(-y_one_hot * torch.log(prob), axis=1).mean()
    # ------END OF YOUR CODE------
    return pred_y, loss
  def backward(self):
    y, grad = self.cache
    N, F = grad.shape
    ####################
    # TODO:
    # 1. Derive the gradient of `net_out` and store the result in variable `grad`
    ####################
    # -----START OF YOUR CODE-----
    grad[torch.arange(N), y] -= 1
    grad /= N
    # ------END OF YOUR CODE------
    return grad

# %%
layer = Softmax_CrossEntropy()
SCE_Tests(layer)
# Out:
# Results of softmax and cross entropy forward and backward tests: All passed.

# %% [markdown]
# ## Network Definition

# %%
class Classifier(object):
  def __init__(self, dim_in, dim_hidden, dim_out, device='cpu'):
    self.dv = device
    np.random.seed(0)
    self.params = {'w1': torch.from_numpy(np.random.randn(dim_in, dim_hidden)*0.8).to(self.dv),
             'b1': torch.zeros(dim_hidden).to(self.dv),
             'w2': torch.from_numpy(np.random.randn(dim_hidden, dim_out)*0.8).to(self.dv),
             'b2': torch.zeros(dim_out).to(self.dv)}
    layer1 = FullyConnectedLayer()
    activation = ReLU()
    layer2 = FullyConnectedLayer()
    self.net = [layer1, activation, layer2]
    self.loss_func = Softmax_CrossEntropy()
  def save_model(self, path):
    torch.save(self.params, path)
  def load_model(self, path):
    checkpoint = torch.load(path, map_location=self.dv)
    self.params = checkpoint
  def training(self, train_dataloader, valid_dataloader, epochs=200, learning_rate=1e-3, learning_rate_decay=0.95, verbose=1):
    print(f'Training with batch_size={train_dataloader[0][0].shape[0]}, hidden_dim={self.params["w1"].shape[1]}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}')
    train_loss_log = []
    train_acc_log = []
    valid_loss_log = []
    valid_acc_log = []
    best_val_loss = None
    for epoch in range(epochs):
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(f'Epoch {epoch+1}:')
      single_epoch_log = ''
      train_loss = 0.0
      train_corr = 0.0; train_eval = 0.0
      for batch_idx in range(len(train_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = train_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        train_loss += loss.cpu().numpy()
        train_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        train_eval += batch_img.shape[0]
        ### Backpropagation and Optimization ###
        params_grad = {}
        dloss_dout2 = self.loss_func.backward()
        dout2_dw2, dout2_db2 = self.net[2].backward(dloss_dout2)
        params_grad['w2'] = dout2_dw2; params_grad['b2'] = dout2_db2
        dout2_dout1 = self.net[1].backward(dloss_dout2.mm(self.params['w2'].T))
        dout1_dw1, dout1_db1 = self.net[0].backward(dout2_dout1)
        params_grad['w1'] = dout1_dw1; params_grad['b1'] = dout1_db1
        ####################
        # TODO:
        # 1. Update model parameters, i.e., `self.params`, by gradient descent
        ####################
        # -----START OF YOUR CODE-----
        self.params['w1'] -= learning_rate * params_grad['w1']
        self.params['b1'] -= learning_rate * params_grad['b1']
        self.params['w2'] -= learning_rate * params_grad['w2']
        self.params['b2'] -= learning_rate * params_grad['b2']
        # ------END OF YOUR CODE------
      train_loss_log.append(train_loss/train_eval)
      train_acc_log.append(100*train_corr/train_eval)
      single_epoch_log += f'Training accuracy: {format(train_acc_log[-1], ".2f")}%, loss: {format(train_loss_log[-1], ".4f")}\n'
      train_dataloader.shuffle()

      valid_loss = 0.0
      valid_corr = 0.0; valid_eval = 0.0
      for batch_idx in range(len(valid_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = valid_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        valid_loss += loss.cpu().numpy()
        valid_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        valid_eval += batch_img.shape[0]
      valid_loss_log.append(valid_loss/valid_eval)
      valid_acc_log.append(100*valid_corr/valid_eval)
      single_epoch_log += f'Validaion accuracy: {format(valid_acc_log[-1], ".2f")}%, loss: {format(valid_loss_log[-1], ".4f")}'
      if best_val_loss is None or valid_loss < best_val_loss:
        best_val_loss = valid_loss
        self.save_model(MODEL_PATH)
        if verbose == 1:
          single_epoch_log = '[MODEL SAVED]\n' + single_epoch_log
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(single_epoch_log)
      learning_rate *= learning_rate_decay # update learning_rate every epoch
    return train_loss_log,train_acc_log,valid_loss_log,valid_acc_log
  def test(self, test_dataloader):
    total_corr = 0; total_eval = 0
    for batch_idx in range(len(test_dataloader)):
      ### Model Input ###
      batch_data = test_dataloader[batch_idx]
      batch_img, batch_label = batch_data
      layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
      layer1_out = self.net[1].forward(layer1_out)
      layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
      pred_y, _ = self.loss_func.forward(batch_label, layer2_out)
      total_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
      total_eval += batch_img.shape[0]
    print(f'Got {total_corr} correct prediction in {total_eval} test data, accuracy: {format((total_corr*1.0/total_eval)*100, ".2f")}%')

# %% [markdown]
# ## Searching for Best Hyperparameters
# Hyperparameters are configuration variables that set by users before model training. They influence the learning process and the final performance of the model. The goal of selecting optimal hyperparameters is to improve the model's accuracy and generalization ability.
#
# Hyperparameters in this assignment include hidden layer size, batch size, learning rate, and learning rate decay. You may change candidate values of them in the following cells and observe which might be useful to optimize the model. Howerver,  as running the whole section may take a while, you are allowed to not running all of the cells.

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Hyperparameters
BATCH_SIZE = 16
LR = 1e-3
LR_DECAY = 0.95
HIDEEN_DIM = 64

# %%
lr_cand = [1e-2, 1e-3, 1e-4]
train_acc = []
valid_acc = []

for lr in lr_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=lr, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=64, learning_rate=0.01, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.0001, learning_rate_decay=0.95

# %%
bs_cand = [8, 16, 100]
train_acc = []
valid_acc = []

for bs in bs_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=bs)
  valid_dataloader = Dataloader(valid_dataset, batch_size=bs)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(bs_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=8, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=100, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95

# %%
hd_cand = [32, 64, 256]
train_acc = []
valid_acc = []

for hd in hd_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, hd, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(hd_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=32, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=256, learning_rate=0.001, learning_rate_decay=0.95

# %%
lr_decay_cand = [1.0, 0.95, 0.9]
train_acc = []
valid_acc = []

for lrd in lr_decay_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=lrd, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_decay_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=1.0
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.9

# %% [markdown]
# ## Training with Best Hyperparameters

# %%
# Please set your hyperparameters here
BATCH_SIZE = 16
LR = 2e-3
LR_DECAY = 0.98
HIDEEN_DIM = 128

# %%
train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
train_loss, train_acc, valid_loss, valid_acc = model.training(train_dataloader, valid_dataloader, learning_rate=LR, learning_rate_decay=LR_DECAY)
plot_result(train_loss, train_acc, valid_loss, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=128, learning_rate=0.002, learning_rate_decay=0.98
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 14.37%, loss: 4.2484
# Validaion accuracy: 11.43%, loss: 3.6242
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 17.21%, loss: 2.9634
# Validaion accuracy: 13.66%, loss: 2.9900
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 18.32%, loss: 2.4795
# Validaion accuracy: 14.20%, loss: 2.7162
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 18.12%, loss: 2.2688
# Validaion accuracy: 17.47%, loss: 2.3202
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 19.68%, loss: 2.0392
# Validaion accuracy: 17.48%, loss: 2.1398
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 21.07%, loss: 1.8612
# Validaion accuracy: 17.05%, loss: 2.0011
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 19.94%, loss: 1.8074
# Validaion accuracy: 17.84%, loss: 1.8933
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 22.22%, loss: 1.6480
# Validaion accuracy: 20.35%, loss: 1.7868
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 21.58%, loss: 1.5314
# Validaion accuracy: 19.94%, loss: 1.7377
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 22.11%, loss: 1.4932
# Validaion accuracy: 21.40%, loss: 1.5659
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 23.73%, loss: 1.3920
# Validaion accuracy: 21.62%, loss: 1.5352
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 22.34%, loss: 1.3182
# Validaion accuracy: 22.68%, loss: 1.4021
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 25.04%, loss: 1.1933
# Validaion accuracy: 22.58%, loss: 1.3556
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 25.05%, loss: 1.1712
# Validaion accuracy: 21.63%, loss: 1.3134
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 26.43%, loss: 1.0959
# Validaion accuracy: 23.24%, loss: 1.2545
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 24.53%, loss: 1.1036
# Validaion accuracy: 22.84%, loss: 1.2074
# Epoch 17:
# Training accuracy: 23.14%, loss: 1.0154
# Validaion accuracy: 20.63%, loss: 1.2268
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 23.19%, loss: 0.9960
# Validaion accuracy: 23.13%, loss: 1.1084
# Epoch 19:
# Training accuracy: 25.06%, loss: 0.9226
# Validaion accuracy: 20.94%, loss: 1.1164
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 24.13%, loss: 0.9405
# Validaion accuracy: 22.84%, loss: 1.0622
# Epoch 21:
# [MODEL SAVED]
# Training accuracy: 25.19%, loss: 0.8778
# Validaion accuracy: 22.94%, loss: 1.0516
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 24.52%, loss: 0.8731
# Validaion accuracy: 23.74%, loss: 0.9551
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 24.89%, loss: 0.8058
# Validaion accuracy: 22.97%, loss: 0.9267
# Epoch 24:
# Training accuracy: 26.70%, loss: 0.7524
# Validaion accuracy: 22.48%, loss: 0.9272
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 27.56%, loss: 0.7221
# Validaion accuracy: 18.61%, loss: 0.9259
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 25.73%, loss: 0.7349
# Validaion accuracy: 23.98%, loss: 0.8432
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 26.45%, loss: 0.7085
# Validaion accuracy: 23.70%, loss: 0.8101
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 26.09%, loss: 0.6753
# Validaion accuracy: 22.48%, loss: 0.8058
# Epoch 29:
# [MODEL SAVED]
# Training accuracy: 25.84%, loss: 0.6463
# Validaion accuracy: 22.35%, loss: 0.7590
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 26.53%, loss: 0.6489
# Validaion accuracy: 24.21%, loss: 0.7330
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 27.80%, loss: 0.6118
# Validaion accuracy: 23.06%, loss: 0.6961
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 26.61%, loss: 0.5812
# Validaion accuracy: 24.99%, loss: 0.6770
# Epoch 33:
# [MODEL SAVED]
# Training accuracy: 26.99%, loss: 0.5905
# Validaion accuracy: 25.37%, loss: 0.6478
# Epoch 34:
# [MODEL SAVED]
# Training accuracy: 26.49%, loss: 0.5564
# Validaion accuracy: 24.46%, loss: 0.6402
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 26.08%, loss: 0.5436
# Validaion accuracy: 24.91%, loss: 0.6005
# Epoch 36:
# Training accuracy: 26.17%, loss: 0.5236
# Validaion accuracy: 22.77%, loss: 0.6250
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 27.48%, loss: 0.4961
# Validaion accuracy: 23.99%, loss: 0.5607
# Epoch 38:
# [MODEL SAVED]
# Training accuracy: 25.43%, loss: 0.5005
# Validaion accuracy: 23.74%, loss: 0.5571
# Epoch 39:
# [MODEL SAVED]
# Training accuracy: 26.38%, loss: 0.4605
# Validaion accuracy: 22.69%, loss: 0.5307
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 26.84%, loss: 0.4686
# Validaion accuracy: 24.39%, loss: 0.5228
# Epoch 41:
# [MODEL SAVED]
# Training accuracy: 27.39%, loss: 0.4422
# Validaion accuracy: 24.23%, loss: 0.4972
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 27.18%, loss: 0.4223
# Validaion accuracy: 24.95%, loss: 0.4784
# Epoch 43:
# [MODEL SAVED]
# Training accuracy: 26.04%, loss: 0.4218
# Validaion accuracy: 23.39%, loss: 0.4784
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 25.64%, loss: 0.4195
# Validaion accuracy: 23.74%, loss: 0.4481
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 26.68%, loss: 0.3740
# Validaion accuracy: 23.74%, loss: 0.4403
# Epoch 46:
# Training accuracy: 27.50%, loss: 0.3667
# Validaion accuracy: 23.05%, loss: 0.4436
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 26.19%, loss: 0.3783
# Validaion accuracy: 24.55%, loss: 0.4226
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 28.28%, loss: 0.3541
# Validaion accuracy: 24.73%, loss: 0.4120
# Epoch 49:
# [MODEL SAVED]
# Training accuracy: 26.82%, loss: 0.3511
# Validaion accuracy: 25.81%, loss: 0.4079
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 27.09%, loss: 0.3472
# Validaion accuracy: 25.18%, loss: 0.4015
# Epoch 51:
# [MODEL SAVED]
# Training accuracy: 27.75%, loss: 0.3421
# Validaion accuracy: 24.69%, loss: 0.3732
# Epoch 52:
# Training accuracy: 28.33%, loss: 0.3201
# Validaion accuracy: 23.15%, loss: 0.3974
# Epoch 53:
# [MODEL SAVED]
# Training accuracy: 27.20%, loss: 0.3203
# Validaion accuracy: 23.07%, loss: 0.3728
# Epoch 54:
# [MODEL SAVED]
# Training accuracy: 26.27%, loss: 0.3177
# Validaion accuracy: 24.76%, loss: 0.3682
# Epoch 55:
# [MODEL SAVED]
# Training accuracy: 26.62%, loss: 0.3011
# Validaion accuracy: 23.51%, loss: 0.3480
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 26.51%, loss: 0.2874
# Validaion accuracy: 25.05%, loss: 0.3314
# Epoch 57:
# [MODEL SAVED]
# Training accuracy: 27.23%, loss: 0.2907
# Validaion accuracy: 24.58%, loss: 0.3208
# Epoch 58:
# Training accuracy: 27.33%, loss: 0.2739
# Validaion accuracy: 23.02%, loss: 0.3240
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 27.03%, loss: 0.2831
# Validaion accuracy: 24.02%, loss: 0.3135
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 26.86%, loss: 0.2725
# Validaion accuracy: 26.76%, loss: 0.3073
# Epoch 61:
# Training accuracy: 27.80%, loss: 0.2607
# Validaion accuracy: 23.57%, loss: 0.3119
# Epoch 62:
# [MODEL SAVED]
# Training accuracy: 27.51%, loss: 0.2628
# Validaion accuracy: 24.62%, loss: 0.2904
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 29.04%, loss: 0.2384
# Validaion accuracy: 25.13%, loss: 0.2836
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 29.59%, loss: 0.2358
# Validaion accuracy: 25.63%, loss: 0.2815
# Epoch 65:
# Training accuracy: 30.94%, loss: 0.2399
# Validaion accuracy: 24.39%, loss: 0.2825
# Epoch 66:
# [MODEL SAVED]
# Training accuracy: 27.05%, loss: 0.2481
# Validaion accuracy: 22.53%, loss: 0.2794
# Epoch 67:
# [MODEL SAVED]
# Training accuracy: 30.45%, loss: 0.2261
# Validaion accuracy: 25.81%, loss: 0.2683
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 29.71%, loss: 0.2329
# Validaion accuracy: 25.62%, loss: 0.2660
# Epoch 69:
# [MODEL SAVED]
# Training accuracy: 29.07%, loss: 0.2284
# Validaion accuracy: 23.95%, loss: 0.2647
# Epoch 70:
# [MODEL SAVED]
# Training accuracy: 29.29%, loss: 0.2244
# Validaion accuracy: 25.56%, loss: 0.2493
# Epoch 71:
# [MODEL SAVED]
# Training accuracy: 27.45%, loss: 0.2300
# Validaion accuracy: 28.50%, loss: 0.2492
# Epoch 72:
# [MODEL SAVED]
# Training accuracy: 30.26%, loss: 0.2113
# Validaion accuracy: 26.62%, loss: 0.2465
# Epoch 73:
# Training accuracy: 27.83%, loss: 0.2131
# Validaion accuracy: 23.39%, loss: 0.2625
# Epoch 74:
# [MODEL SAVED]
# Training accuracy: 28.76%, loss: 0.2180
# Validaion accuracy: 24.57%, loss: 0.2401
# Epoch 75:
# Training accuracy: 29.44%, loss: 0.2066
# Validaion accuracy: 25.51%, loss: 0.2432
# Epoch 76:
# [MODEL SAVED]
# Training accuracy: 27.50%, loss: 0.2105
# Validaion accuracy: 25.17%, loss: 0.2353
# Epoch 77:
# Training accuracy: 28.18%, loss: 0.2175
# Validaion accuracy: 24.57%, loss: 0.2381
# Epoch 78:
# [MODEL SAVED]
# Training accuracy: 28.51%, loss: 0.1976
# Validaion accuracy: 25.44%, loss: 0.2246
# Epoch 79:
# Training accuracy: 29.94%, loss: 0.1959
# Validaion accuracy: 24.41%, loss: 0.2278
# Epoch 80:
# [MODEL SAVED]
# Training accuracy: 29.46%, loss: 0.1981
# Validaion accuracy: 25.44%, loss: 0.2198
# Epoch 81:
# Training accuracy: 30.33%, loss: 0.1949
# Validaion accuracy: 24.74%, loss: 0.2277
# Epoch 82:
# [MODEL SAVED]
# Training accuracy: 29.74%, loss: 0.2038
# Validaion accuracy: 27.02%, loss: 0.2187
# Epoch 83:
# Training accuracy: 30.50%, loss: 0.1985
# Validaion accuracy: 26.23%, loss: 0.2204
# Epoch 84:
# [MODEL SAVED]
# Training accuracy: 29.34%, loss: 0.1877
# Validaion accuracy: 27.06%, loss: 0.2170
# Epoch 85:
# Training accuracy: 30.98%, loss: 0.1928
# Validaion accuracy: 25.39%, loss: 0.2174
# Epoch 86:
# [MODEL SAVED]
# Training accuracy: 29.03%, loss: 0.1975
# Validaion accuracy: 25.24%, loss: 0.2124
# Epoch 87:
# [MODEL SAVED]
# Training accuracy: 30.50%, loss: 0.1881
# Validaion accuracy: 26.52%, loss: 0.2107
# Epoch 88:
# [MODEL SAVED]
# Training accuracy: 31.51%, loss: 0.1858
# Validaion accuracy: 27.06%, loss: 0.2100
# Epoch 89:
# [MODEL SAVED]
# Training accuracy: 30.23%, loss: 0.1850
# Validaion accuracy: 27.70%, loss: 0.2072
# Epoch 90:
# Training accuracy: 28.22%, loss: 0.1937
# Validaion accuracy: 25.31%, loss: 0.2171
# Epoch 91:
# [MODEL SAVED]
# Training accuracy: 31.13%, loss: 0.1899
# Validaion accuracy: 27.90%, loss: 0.2028
# Epoch 92:
# Training accuracy: 30.09%, loss: 0.1779
# Validaion accuracy: 24.49%, loss: 0.2034
# Epoch 93:
# Training accuracy: 29.83%, loss: 0.1894
# Validaion accuracy: 27.46%, loss: 0.2036
# Epoch 94:
# [MODEL SAVED]
# Training accuracy: 29.74%, loss: 0.1828
# Validaion accuracy: 26.59%, loss: 0.1995
# Epoch 95:
# [MODEL SAVED]
# Training accuracy: 29.85%, loss: 0.1785
# Validaion accuracy: 26.22%, loss: 0.1982
# Epoch 96:
# [MODEL SAVED]
# Training accuracy: 31.64%, loss: 0.1776
# Validaion accuracy: 28.32%, loss: 0.1956
# Epoch 97:
# [MODEL SAVED]
# Training accuracy: 31.34%, loss: 0.1858
# Validaion accuracy: 27.92%, loss: 0.1927
# Epoch 98:
# Training accuracy: 29.76%, loss: 0.1776
# Validaion accuracy: 27.08%, loss: 0.1971
# Epoch 99:
# Training accuracy: 31.97%, loss: 0.1769
# Validaion accuracy: 26.58%, loss: 0.1953
# Epoch 100:
# Training accuracy: 31.04%, loss: 0.1734
# Validaion accuracy: 27.31%, loss: 0.1948
# Epoch 101:
# Training accuracy: 29.65%, loss: 0.1775
# Validaion accuracy: 25.84%, loss: 0.1944
# Epoch 102:
# [MODEL SAVED]
# Training accuracy: 29.97%, loss: 0.1741
# Validaion accuracy: 30.09%, loss: 0.1904
# Epoch 103:
# Training accuracy: 30.56%, loss: 0.1817
# Validaion accuracy: 27.93%, loss: 0.1904
# Epoch 104:
# Training accuracy: 29.40%, loss: 0.1747
# Validaion accuracy: 25.11%, loss: 0.1921
# Epoch 105:
# Training accuracy: 31.55%, loss: 0.1710
# Validaion accuracy: 28.25%, loss: 0.1930
# Epoch 106:
# Training accuracy: 32.33%, loss: 0.1720
# Validaion accuracy: 27.44%, loss: 0.1967
# Epoch 107:
# Training accuracy: 30.88%, loss: 0.1810
# Validaion accuracy: 24.67%, loss: 0.1958
# Epoch 108:
# Training accuracy: 28.93%, loss: 0.1759
# Validaion accuracy: 26.18%, loss: 0.1909
# Epoch 109:
# [MODEL SAVED]
# Training accuracy: 30.76%, loss: 0.1782
# Validaion accuracy: 26.98%, loss: 0.1893
# Epoch 110:
# Training accuracy: 28.84%, loss: 0.1714
# Validaion accuracy: 24.25%, loss: 0.1967
# Epoch 111:
# [MODEL SAVED]
# Training accuracy: 31.44%, loss: 0.1637
# Validaion accuracy: 28.79%, loss: 0.1847
# Epoch 112:
# Training accuracy: 31.52%, loss: 0.1722
# Validaion accuracy: 25.98%, loss: 0.1863
# Epoch 113:
# Training accuracy: 28.14%, loss: 0.1698
# Validaion accuracy: 28.26%, loss: 0.1848
# Epoch 114:
# [MODEL SAVED]
# Training accuracy: 31.69%, loss: 0.1671
# Validaion accuracy: 27.87%, loss: 0.1835
# Epoch 115:
# [MODEL SAVED]
# Training accuracy: 28.36%, loss: 0.1843
# Validaion accuracy: 27.80%, loss: 0.1827
# Epoch 116:
# Training accuracy: 31.53%, loss: 0.1680
# Validaion accuracy: 28.04%, loss: 0.1830
# Epoch 117:
# Training accuracy: 31.06%, loss: 0.1707
# Validaion accuracy: 28.17%, loss: 0.1832
# Epoch 118:
# Training accuracy: 30.75%, loss: 0.1654
# Validaion accuracy: 26.85%, loss: 0.1829
# Epoch 119:
# [MODEL SAVED]
# Training accuracy: 30.92%, loss: 0.1618
# Validaion accuracy: 28.88%, loss: 0.1819
# Epoch 120:
# Training accuracy: 29.16%, loss: 0.1755
# Validaion accuracy: 25.69%, loss: 0.1863
# Epoch 121:
# [MODEL SAVED]
# Training accuracy: 30.04%, loss: 0.1624
# Validaion accuracy: 29.70%, loss: 0.1787
# Epoch 122:
# Training accuracy: 31.18%, loss: 0.1675
# Validaion accuracy: 28.13%, loss: 0.1837
# Epoch 123:
# Training accuracy: 29.89%, loss: 0.1696
# Validaion accuracy: 29.72%, loss: 0.1804
# Epoch 124:
# Training accuracy: 30.88%, loss: 0.1616
# Validaion accuracy: 28.17%, loss: 0.1810
# Epoch 125:
# Training accuracy: 29.83%, loss: 0.1733
# Validaion accuracy: 27.32%, loss: 0.1822
# Epoch 126:
# Training accuracy: 28.49%, loss: 0.1656
# Validaion accuracy: 27.73%, loss: 0.1792
# Epoch 127:
# [MODEL SAVED]
# Training accuracy: 28.54%, loss: 0.1702
# Validaion accuracy: 28.71%, loss: 0.1769
# Epoch 128:
# Training accuracy: 29.51%, loss: 0.1654
# Validaion accuracy: 29.04%, loss: 0.1779
# Epoch 129:
# Training accuracy: 30.70%, loss: 0.1674
# Validaion accuracy: 28.90%, loss: 0.1789
# Epoch 130:
# Training accuracy: 31.93%, loss: 0.1683
# Validaion accuracy: 29.52%, loss: 0.1798
# Epoch 131:
# Training accuracy: 33.24%, loss: 0.1632
# Validaion accuracy: 29.48%, loss: 0.1780
# Epoch 132:
# Training accuracy: 29.33%, loss: 0.1659
# Validaion accuracy: 26.58%, loss: 0.1817
# Epoch 133:
# [MODEL SAVED]
# Training accuracy: 29.46%, loss: 0.1791
# Validaion accuracy: 28.48%, loss: 0.1747
# Epoch 134:
# Training accuracy: 30.52%, loss: 0.1761
# Validaion accuracy: 28.75%, loss: 0.1763
# Epoch 135:
# Training accuracy: 30.18%, loss: 0.1677
# Validaion accuracy: 26.48%, loss: 0.1773
# Epoch 136:
# Training accuracy: 31.57%, loss: 0.1689
# Validaion accuracy: 28.77%, loss: 0.1776
# Epoch 137:
# Training accuracy: 30.80%, loss: 0.1650
# Validaion accuracy: 29.49%, loss: 0.1756
# Epoch 138:
# Training accuracy: 31.22%, loss: 0.1642
# Validaion accuracy: 28.45%, loss: 0.1765
# Epoch 139:
# Training accuracy: 30.59%, loss: 0.1671
# Validaion accuracy: 29.36%, loss: 0.1768
# Epoch 140:
# Training accuracy: 30.78%, loss: 0.1698
# Validaion accuracy: 28.84%, loss: 0.1749
# Epoch 141:
# [MODEL SAVED]
# Training accuracy: 30.23%, loss: 0.1574
# Validaion accuracy: 29.39%, loss: 0.1747
# Epoch 142:
# [MODEL SAVED]
# Training accuracy: 30.38%, loss: 0.1717
# Validaion accuracy: 29.82%, loss: 0.1744
# Epoch 143:
# Training accuracy: 32.02%, loss: 0.1590
# Validaion accuracy: 27.99%, loss: 0.1757
# Epoch 144:
# Training accuracy: 30.66%, loss: 0.1727
# Validaion accuracy: 25.50%, loss: 0.1783
# Epoch 145:
# [MODEL SAVED]
# Training accuracy: 29.86%, loss: 0.1583
# Validaion accuracy: 29.23%, loss: 0.1718
# Epoch 146:
# Training accuracy: 28.66%, loss: 0.1632
# Validaion accuracy: 27.07%, loss: 0.1747
# Epoch 147:
# Training accuracy: 30.46%, loss: 0.1595
# Validaion accuracy: 30.48%, loss: 0.1726
# Epoch 148:
# Training accuracy: 31.75%, loss: 0.1619
# Validaion accuracy: 27.64%, loss: 0.1747
# Epoch 149:
# [MODEL SAVED]
# Training accuracy: 30.46%, loss: 0.1615
# Validaion accuracy: 29.77%, loss: 0.1715
# Epoch 150:
# Training accuracy: 28.39%, loss: 0.1774
# Validaion accuracy: 27.97%, loss: 0.1758
# Epoch 151:
# Training accuracy: 28.66%, loss: 0.1658
# Validaion accuracy: 28.54%, loss: 0.1728
# Epoch 152:
# Training accuracy: 28.55%, loss: 0.1727
# Validaion accuracy: 26.80%, loss: 0.1736
# Epoch 153:
# Training accuracy: 30.24%, loss: 0.1591
# Validaion accuracy: 27.04%, loss: 0.1742
# Epoch 154:
# Training accuracy: 29.56%, loss: 0.1638
# Validaion accuracy: 26.96%, loss: 0.1743
# Epoch 155:
# [MODEL SAVED]
# Training accuracy: 30.46%, loss: 0.1670
# Validaion accuracy: 30.17%, loss: 0.1711
# Epoch 156:
# Training accuracy: 29.25%, loss: 0.1589
# Validaion accuracy: 28.83%, loss: 0.1724
# Epoch 157:
# Training accuracy: 29.38%, loss: 0.1703
# Validaion accuracy: 30.28%, loss: 0.1715
# Epoch 158:
# Training accuracy: 32.11%, loss: 0.1497
# Validaion accuracy: 29.53%, loss: 0.1712
# Epoch 159:
# Training accuracy: 30.45%, loss: 0.1666
# Validaion accuracy: 27.31%, loss: 0.1731
# Epoch 160:
# Training accuracy: 27.82%, loss: 0.1642
# Validaion accuracy: 28.26%, loss: 0.1713
# Epoch 161:
# Training accuracy: 29.10%, loss: 0.1685
# Validaion accuracy: 28.26%, loss: 0.1720
# Epoch 162:
# [MODEL SAVED]
# Training accuracy: 30.43%, loss: 0.1567
# Validaion accuracy: 30.25%, loss: 0.1701
# Epoch 163:
# Training accuracy: 30.72%, loss: 0.1709
# Validaion accuracy: 29.73%, loss: 0.1722
# Epoch 164:
# Training accuracy: 31.18%, loss: 0.1562
# Validaion accuracy: 28.82%, loss: 0.1708
# Epoch 165:
# [MODEL SAVED]
# Training accuracy: 31.15%, loss: 0.1613
# Validaion accuracy: 29.19%, loss: 0.1696
# Epoch 166:
# Training accuracy: 30.74%, loss: 0.1608
# Validaion accuracy: 29.78%, loss: 0.1701
# Epoch 167:
# Training accuracy: 30.82%, loss: 0.1571
# Validaion accuracy: 28.82%, loss: 0.1723
# Epoch 168:
# Training accuracy: 30.69%, loss: 0.1660
# Validaion accuracy: 27.84%, loss: 0.1716
# Epoch 169:
# Training accuracy: 31.60%, loss: 0.1643
# Validaion accuracy: 29.32%, loss: 0.1707
# Epoch 170:
# Training accuracy: 30.81%, loss: 0.1591
# Validaion accuracy: 29.79%, loss: 0.1697
# Epoch 171:
# [MODEL SAVED]
# Training accuracy: 30.04%, loss: 0.1530
# Validaion accuracy: 31.54%, loss: 0.1688
# Epoch 172:
# Training accuracy: 29.81%, loss: 0.1633
# Validaion accuracy: 29.30%, loss: 0.1691
# Epoch 173:
# Training accuracy: 30.48%, loss: 0.1582
# Validaion accuracy: 27.83%, loss: 0.1705
# Epoch 174:
# Training accuracy: 29.97%, loss: 0.1624
# Validaion accuracy: 30.46%, loss: 0.1696
# Epoch 175:
# Training accuracy: 30.57%, loss: 0.1585
# Validaion accuracy: 27.35%, loss: 0.1697
# Epoch 176:
# Training accuracy: 30.85%, loss: 0.1596
# Validaion accuracy: 30.97%, loss: 0.1693
# Epoch 177:
# Training accuracy: 31.49%, loss: 0.1684
# Validaion accuracy: 28.84%, loss: 0.1690
# Epoch 178:
# Training accuracy: 29.48%, loss: 0.1671
# Validaion accuracy: 29.48%, loss: 0.1688
# Epoch 179:
# Training accuracy: 29.98%, loss: 0.1665
# Validaion accuracy: 29.70%, loss: 0.1692
# Epoch 180:
# [MODEL SAVED]
# Training accuracy: 30.94%, loss: 0.1588
# Validaion accuracy: 29.29%, loss: 0.1682
# Epoch 181:
# [MODEL SAVED]
# Training accuracy: 32.60%, loss: 0.1581
# Validaion accuracy: 28.99%, loss: 0.1680
# Epoch 182:
# Training accuracy: 30.86%, loss: 0.1510
# Validaion accuracy: 29.24%, loss: 0.1683
# Epoch 183:
# Training accuracy: 29.32%, loss: 0.1605
# Validaion accuracy: 30.11%, loss: 0.1690
# Epoch 184:
# [MODEL SAVED]
# Training accuracy: 30.22%, loss: 0.1586
# Validaion accuracy: 30.26%, loss: 0.1673
# Epoch 185:
# Training accuracy: 30.48%, loss: 0.1575
# Validaion accuracy: 30.03%, loss: 0.1684
# Epoch 186:
# Training accuracy: 29.86%, loss: 0.1618
# Validaion accuracy: 28.04%, loss: 0.1684
# Epoch 187:
# Training accuracy: 28.64%, loss: 0.1627
# Validaion accuracy: 30.42%, loss: 0.1674
# Epoch 188:
# Training accuracy: 30.43%, loss: 0.1644
# Validaion accuracy: 28.48%, loss: 0.1689
# Epoch 189:
# Training accuracy: 31.04%, loss: 0.1604
# Validaion accuracy: 29.70%, loss: 0.1687
# Epoch 190:
# Training accuracy: 28.66%, loss: 0.1610
# Validaion accuracy: 29.76%, loss: 0.1675
# Epoch 191:
# Training accuracy: 29.83%, loss: 0.1562
# Validaion accuracy: 29.28%, loss: 0.1675
# Epoch 192:
# Training accuracy: 30.28%, loss: 0.1574
# Validaion accuracy: 29.69%, loss: 0.1685
# Epoch 193:
# [MODEL SAVED]
# Training accuracy: 30.38%, loss: 0.1498
# Validaion accuracy: 30.52%, loss: 0.1672
# Epoch 194:
# Training accuracy: 28.81%, loss: 0.1672
# Validaion accuracy: 29.38%, loss: 0.1685
# Epoch 195:
# Training accuracy: 28.69%, loss: 0.1528
# Validaion accuracy: 28.39%, loss: 0.1685
# Epoch 196:
# Training accuracy: 28.36%, loss: 0.1589
# Validaion accuracy: 30.14%, loss: 0.1676
# Epoch 197:
# Training accuracy: 29.01%, loss: 0.1660
# Validaion accuracy: 30.99%, loss: 0.1686
# Epoch 198:
# [MODEL SAVED]
# Training accuracy: 31.34%, loss: 0.1584
# Validaion accuracy: 30.26%, loss: 0.1667
# Epoch 199:
# Training accuracy: 29.45%, loss: 0.1561
# Validaion accuracy: 29.92%, loss: 0.1675
# Epoch 200:
# Training accuracy: 29.88%, loss: 0.1577
# Validaion accuracy: 31.29%, loss: 0.1671

# %% [markdown]
# Test the model with test_dataset. <font color='red'>The test accuracy must reach at least 28%.</font>

# %%
test_dataloader = Dataloader(test_dataset)
model.load_model(MODEL_PATH)
model.test(test_dataloader)
# Out:
# Got 2879 correct prediction in 10000 test data, accuracy: 28.79%
