# %% [markdown]
# # Introduction
# Colaboratory, or “Colab” for short, is a product from Google Research. Colab allows anybody to write and execute arbitrary python code through the browser, and is especially well suited to machine learning, data analysis and education. More technically, Colab is a hosted Jupyter notebook service that requires no setup to use, while providing access free of charge to computing resources including GPUs.
#
# A Jupyter notebook is made up of cells with python code. You can execute a cell by clicking on it and pressing `Ctrl-Enter`. When you do so, the code in the cell will be executed, and the output of the cell will be displayed beneath the cell.

# %%
x = 5
print(x+3)
# Out:
# 8

# %% [markdown]
# Global variables are shared between cells. Therefore, we can access `x` in the next cell.

# %%
print(x+10)
# Out:
# 15

# %% [markdown]
# By convention, Jupyter notebooks are expected to be run from top to bottom. Failing to execute some cells or executing cells out of order can result in errors.

# %%
# This does not work
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e6faf7a9fd0a> in <module>
#       1 # This does not work
# ----> 2 print(x+y)
#
# NameError: name 'y' is not defined

# %%
# After executing this cell, you can re-evaluate the cell above
y = 3

# %% [markdown]
# Jupyter notebooks can also run Linux commands by adding a `!` at the beginning of each command. For example, you can check python version with the following cell.

# %%
# !python --version
# Out:
# Python 3.8.10

# %% [markdown]
# Make sure you have changed notebook hardware accelerator to GPU before using it.
# ![gpu.png](data:image/png;base64,...)
#
# You can check GPU information by running `!nvidia-smi`.

# %%
# !nvidia-smi
# Out:
# Sun Feb 19 12:31:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    28W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Link to Google Drive
# After mounting your Google Drive with the following cell, you can iteract with your files in your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# You will see files and folders in your Google Drive with running the following cell.

# %%
import os

FOLDER_PATH = '/content/drive/MyDrive/HW1'
print(os.listdir(FOLDER_PATH))
# Out:
# ['greeting.py', '__pycache__', 'sample.png', 'HW1.ipynb']

# %% [markdown]
# Most of your work will involve implementing certain functions in external python files. For example, importting file "greeting.py" in folder "HW1" with the following cell.

# %%
import drive.MyDrive.HW1.greeting
# Out:
# Hello, world!

# %% [markdown]
# # Numpy Tutorial
# Numpy is a high performance framework for operations on multi dimensional arrays.

# %%
import numpy as np

# Create a simple (2, 3) numpy array
# [[ 1  2  3]
#  [ 4  5  6]]
a = np.array([[1,2,3], [4,5,6]])
print('a='); print(a)

# Print the data type of this array
print('Data type:', a.dtype)

# print the shape of this array
print('Shape of data:', a.shape)
# Out:
# a=
# [[1 2 3]
#  [4 5 6]]
# Data type: int64
# Shape of data: (2, 3)

# %%
# Slicing operation 
# Let us take the first two columns from the original array and save it in a new one
b = a[:, :2]
print('b='); print(b)
print('Data type:', b.dtype)
print('Shape of data:', b.shape)
# Out:
# b=
# [[1 2]
#  [4 5]]
# Data type: int64
# Shape of data: (2, 2)

# %%
# Select elements which satisfy a condition
# Using numpy array makes such a selection trivial
print('a='); print(a)
print('')

mask = a > 1
print('mask='); print(mask)
print('')

new_array = a[mask]
print('a[mask]='); print(new_array)
# Out:
# a=
# [[1 2 3]
#  [4 5 6]]
#
# mask=
# [[False  True  True]
#  [ True  True  True]]
#
# a[mask]=
# [2 3 4 5 6]

# %%
# Do the same thing in a single step
c = a[a > 1]
print(np.all(new_array == c)) #  np.all() to indicate that all the values need to match
# Out:
# True

# %%
# Create arrays with same value
print('all-zero (2, 3) array:'); print(np.zeros((2, 3)))
print('')

print('all-one (2, 3) array:'); print(np.ones((2, 3)))
print('')

print('all filled with a constant (2, 3) array:'); print(np.full((2, 3), 2.5))
print('')

print('filled with random values (2, 3) array:'); print(np.random.random((2, 3)))
# Out:
# all-zero (2, 3) array:
# [[0. 0. 0.]
#  [0. 0. 0.]]
#
# all-one (2, 3) array:
# [[1. 1. 1.]
#  [1. 1. 1.]]
#
# all filled with a constant (2, 3) array:
# [[2.5 2.5 2.5]
#  [2.5 2.5 2.5]]
#
# filled with random values (2, 3) array:
# [[0.21313528 0.90207906 0.18355273]
#  [0.3768762  0.55053996 0.70196459]]

# %%
# Mathematical operations
x = np.array([[1,2],[3,4]])
y = np.array([[5,6],[7,8]])

# Elementwise sum; both produce the array
# [[ 6  8]
#  [10 12]]
print('x + y='); print(x + y)
print('numpy.add(x, y)='); print(np.add(x, y))
print('')

# Elementwise difference; both produce the array
# [[-4 -4]
#  [-4 -4]]
print('x - y='); print(x - y)
print('numpy.subtract(x, y)=:'); print(np.subtract(x, y))
print('')

# Elementwise product; both produce the array
# [[ 5 12]
#  [21 32]]
print('x * y='); print(x * y)
print('np.multiply(x, y)='); print(np.multiply(x, y))
print('')

# Elementwise division; both produce the array
# [[0.2      0.33333333]
#  [0.42857143     0.5]]
print('x / y='); print(x / y)
print('np.divide(x, y)='); print(np.divide(x, y))
# Out:
# x + y=
# [[ 6  8]
#  [10 12]]
# numpy.add(x, y)=
# [[ 6  8]
#  [10 12]]
#
# x - y=
# [[-4 -4]
#  [-4 -4]]
# numpy.subtract(x, y)=:
# [[-4 -4]
#  [-4 -4]]
#
# x * y=
# [[ 5 12]
#  [21 32]]
# np.multiply(x, y)=
# [[ 5 12]
#  [21 32]]
#
# x / y=
# [[0.2        0.33333333]
#  [0.42857143 0.5       ]]
# np.divide(x, y)=
# [[0.2        0.33333333]
#  [0.42857143 0.5       ]]

# %%
print('x='); print(x)
print('')

# Element wise operations
# Elementwise square root; produces the array
# [[1.       1.41421356]
#  [1.73205081      2.]]
print('np.sqrt(x)='); print(np.sqrt(x))
print('')

# Element wise exponential operation
# [[ 2.71828183  7.3890561]
#  [20.08553692  54.59815003]]
print('np.exp(x)='); print(np.exp(x))
# Out:
# x=
# [[1 2]
#  [3 4]]
#
# np.sqrt(x)=
# [[1.         1.41421356]
#  [1.73205081 2.        ]]
#
# np.exp(x)=
# [[ 2.71828183  7.3890561 ]
#  [20.08553692 54.59815003]]

# %% [markdown]
# Broadcasting is a powerful mechanism that allows numpy to work with arrays of different shapes when performing arithmetic operations. Frequently we have a smaller array and a larger array, and we want to use the smaller array multiple times to perform some operation on the larger array.

# %%
x = np.array([[1,2], [3,4], [5,6]])
print('x='); print(x)
print('')
y = np.array([2, 3])
print('y='); print(y)
print('')
print('x + y='); print(x + y)
# Out:
# x=
# [[1 2]
#  [3 4]
#  [5 6]]
#
# y=
# [2 3]
#
# x + y=
# [[3 5]
#  [5 7]
#  [7 9]]

# %%
x = np.array([[1,2], [3,4], [5,6]])
print('x='); print(x)
print('')
y = np.array([1, 0])
print('y='); print(y)
print('')
print('x * y='); print(x * y)
# Out:
# x=
# [[1 2]
#  [3 4]
#  [5 6]]
#
# y=
# [1 0]
#
# x * y=
# [[1 0]
#  [3 0]
#  [5 0]]

# %%
x = np.array([[1,2], [3,4], [5,6]])
print('x='); print(x)
print('')
y = np.array([[1],[0],[1]])
print('y='); print(y)
print('')
print('x * y='); print(x * y)
# Out:
# x=
# [[1 2]
#  [3 4]
#  [5 6]]
#
# y=
# [[1]
#  [0]
#  [1]]
#
# x * y=
# [[1 2]
#  [0 0]
#  [5 6]]

# %%
# Example that dimensions of inputs not match and broadcasting fails
x = np.array([[1,2], [3,4], [5,6]])
print('x='); print(x)
print('')
y = np.array([1, 0, 1])
print('y='); print(y)
print('')
print('x * y='); print(x * y)
# Out:
# x=
# [[1 2]
#  [3 4]
#  [5 6]]
#
# y=
# [1 0 1]
#
# x * y=
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-43973e5a0e7b> in <module>
#       6 print('y='); print(y)
#       7 print('')
# ----> 8 print('x * y='); print(x * y)
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %% [markdown]
# # Matplotlib Tutorial
# Matplotlib is a drawing library that supports various drawing types(scatter plot, line chart, bar chart, etc.), it can also display images.

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y, marker='o', linestyle='-', color='purple')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import skimage.io as io

IMG_PATH = '/content/drive/MyDrive/HW1/sample.png'
img = io.imread(IMG_PATH)

plt.imshow(img)

# %% [markdown]
# # Pytorch Tutorial
# Numpy cannot utilize GPU to accelerate its numerical computations. Therefore, we need to convert numpy array to torch tensor before applying data into deep learning model.

# %% [markdown]
# ## Machine Learning
# ![ml.png](data:image/png;base64,...)
# ![neuron.png](data:image/png;base64,...)

# %% [markdown]
# ## Linear Regression with Single Neuron

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

xs = []; ys = []

for idx in range(50):
  x = random.uniform(0, 10); y = x * 0.5 + 0.3 + random.uniform(-0.2, 0.2)
  xs.append(x); ys.append(y)

data = np.array(xs, dtype=np.float32)
ground_truth = np.array(ys, dtype=np.float32)

plt.rcParams["figure.figsize"] = (8, 7)
plt.plot(xs, ys, 'ro')
plt.title(f'Regression line: f(x) = 0.5x + 0.3 + noise')
plt.xlabel('x'); plt.ylabel('f(x)')
plt.show()

# %%
import torch
import torch.nn as nn
from torch.optim import optimizer

print(f'Shape of data: {data.shape}, Type of data: {type(data)}')
print(f'Shape of ground truth: {ground_truth.shape}, Type of ground truth: {type(ground_truth)}')

data = torch.from_numpy(data).unsqueeze(1)
ground_truth = torch.from_numpy(ground_truth).unsqueeze(1)
print(f'Shape of data: {data.shape}, Type of data: {type(data)}')
print(f'Shape of ground truth: {ground_truth.shape}, Type of ground truth: {type(ground_truth)}')

class LinearRegression(nn.Module):
  def __init__(self, input_dim, output_dim):
    super(LinearRegression, self).__init__()
    self.learner = nn.Linear(input_dim, output_dim)
    nn.init.zeros_(self.learner.weight); nn.init.zeros_(self.learner.bias)
  def forward(self, x):
    return self.learner(x)
  def get_params(self):
    return self.learner.weight.detach().numpy()[0][0], self.learner.bias.detach().numpy()[0]
# Out:
# Shape of data: (50,), Type of data: <class 'numpy.ndarray'>
# Shape of ground truth: (50,), Type of ground truth: <class 'numpy.ndarray'>
# Shape of data: torch.Size([50, 1]), Type of data: <class 'torch.Tensor'>
# Shape of ground truth: torch.Size([50, 1]), Type of ground truth: <class 'torch.Tensor'>

# %%
model = LinearRegression(1, 1)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=5e-4)
weights = []; biases = []; losses = []
max_loss = -1

epochs = 100
xt = [1, 2, 5, 10, 50, epochs]
for epoch in range(epochs):
  loss = 0
  for idx in range(len(data)):
    pred = model(data[idx])
    loss += criterion(pred, ground_truth[idx])
  loss.backward()
  optimizer.step()
  optimizer.zero_grad()
  if epoch+1 in xt:
    w, b = model.get_params()
    weights.append(w); biases.append(b); losses.append(loss.detach().numpy())
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    ax1.plot(xs, ys, 'ro')
    mx = [-2, 12]
    my = [mx[0]*w+b, mx[1]*w+b]
    ax1.plot(mx, my, 'k-')
    ax1.set_xlim([-0.5, 10.5]); ax1.set_ylim([-0.5, 6.5])
    ax1.set_xlabel('x'); ax1.set_ylabel('y')
    if b < 0:
      ax1.set_title(f'Regression line: y={"{0:.4f}".format(w)}x{"{0:.4f}".format(b)}')
    else:
      ax1.set_title(f'Regression line: y={"{0:.4f}".format(w)}x+{"{0:.4f}".format(b)}')
    
    if max_loss == -1:
      max_loss = loss.detach().numpy()
    ax2.plot(range(1, len(losses)+1), losses, '-o')
    plt.xticks(range(1, 7), xt)
    ax2.set_xlim([0.5, 6.5]); ax2.set_ylim([-2.5, max_loss+2.5])
    ax2.set_title(f'Losses (epoch {epoch+1} loss: {"{0:.4f}".format(loss)})')
    ax2.set_xlabel('epoch')
    print(f'Epoch: {epoch+1}, Loss = {loss.item(): .4f}, Model parameters = [w: {w}, b: {b}]')
    plt.show()
# Out:
# Epoch: 1, Loss =  556.4158, Model parameters = [w: 1.0156749486923218, b: 0.15233448147773743]
# Epoch: 2, Loss =  449.9324, Model parameters = [w: 0.10199717432260513, b: 0.018955370411276817]
# Epoch: 5, Loss =  238.0502, Model parameters = [w: 0.8478493690490723, b: 0.1350420117378235]
# Epoch: 10, Loss =  82.7286, Model parameters = [w: 0.3477044403553009, b: 0.07003490626811981]
# Epoch: 50, Loss =  0.7646, Model parameters = [w: 0.5211502909660339, b: 0.15455412864685059]
# Epoch: 100, Loss =  0.6545, Model parameters = [w: 0.51678067445755, b: 0.20202946662902832]

# %% [markdown]
# ## Binary Classification with Single Neuron

# %%
import numpy as np
import random
from matplotlib import pyplot as plt

x1s = []; x2s = []; ys = []
ax1s = []; ax2s = [] # (x1, x2) in class a, labeled as 0
bx1s = []; bx2s = [] # (x1, x2) in class b, labeled as 1

for idx in range(100):
  x1 = random.uniform(0, 10); x2 = random.uniform(0, 10)
  x1s.append(x1); x2s.append(x2)
  if x1 * 0.4 + 2.5 - x2 < 0:
    ax1s.append(x1); ax2s.append(x2)
    ys.append(0)
  else:
    bx1s.append(x1); bx2s.append(x2)
    ys.append(1)

data = np.dstack((np.array(x1s, dtype=np.float32), np.array(x2s, dtype=np.float32)))
ground_truth = np.array(ys, dtype=np.float32)

plt.rcParams["figure.figsize"] = (8, 7)
plt.plot(ax1s, ax2s, 'ro')
plt.plot(bx1s, bx2s, 'bo')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title(f'Classifier: x2 = 0.4x1 + 2.5')
plt.show()

# %%
import torch
import torch.nn as nn
from torch.optim import optimizer

print(f'Shape of data: {data.shape}, Type of data: {type(data)}')
print(f'Shape of ground truth: {ground_truth.shape}, Type of ground truth: {type(ground_truth)}')

data = torch.from_numpy(data).permute(1, 2, 0).squeeze(-1)
ground_truth = torch.from_numpy(ground_truth).unsqueeze(1)
print(f'Shape of data: {data.shape}, Type of data: {type(data)}')
print(f'Shape of ground truth: {ground_truth.shape}, Type of ground truth: {type(ground_truth)}')

class BinaryClassification(nn.Module):
  def __init__(self, input_dim, output_dim):
    super(BinaryClassification, self).__init__()
    self.learner = nn.Linear(input_dim, output_dim)
    nn.init.zeros_(self.learner.weight); nn.init.zeros_(self.learner.bias)
  def forward(self, x):
    return torch.sigmoid(self.learner(x))
  def get_params(self):
    return self.learner.weight.detach().numpy()[0][0], self.learner.weight.detach().numpy()[0][1], self.learner.bias.detach().numpy()[0]
# Out:
# Shape of data: (1, 100, 2), Type of data: <class 'numpy.ndarray'>
# Shape of ground truth: (100,), Type of ground truth: <class 'numpy.ndarray'>
# Shape of data: torch.Size([100, 2]), Type of data: <class 'torch.Tensor'>
# Shape of ground truth: torch.Size([100, 1]), Type of ground truth: <class 'torch.Tensor'>

# %%
model = BinaryClassification(2, 1)
criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=2e-3)
weights = []; biases = []; losses = []
max_loss = -1

epochs = 1000
xt = [1, 2, 10, 100, 500, epochs]
for epoch in range(epochs):
  loss = 0
  for idx in range(len(data)):
    pred = model(data[idx])
    loss += criterion(pred, ground_truth[idx])
  loss.backward()
  optimizer.step()
  optimizer.zero_grad()
  if epoch+1 in xt:
    w1, w2, b = model.get_params()
    w = -w1/w2; b = -b/w2
    weights.append(w); biases.append(b); losses.append(loss.detach().numpy())
    f, (sub1, sub2) = plt.subplots(1, 2, figsize=(10, 5))
    sub1.plot(ax1s, ax2s, 'ro')
    sub1.plot(bx1s, bx2s, 'bo')
    mx1 = [-2, 12]
    mx2 = [mx1[0]*w+b, mx1[1]*w+b]
    sub1.plot(mx1, mx2, 'k-')
    sub1.set_xlim([-0.5, 10.5]); sub1.set_ylim([-0.5, 10.5])
    sub1.set_xlabel('x1'); sub1.set_ylabel('x2')
    if b < 0:
      sub1.set_title(f'Classifier: x2={"{0:.4f}".format(w)}x1{"{0:.4f}".format(b)}')
    else:
      sub1.set_title(f'Classifier: x2={"{0:.4f}".format(w)}x1+{"{0:.4f}".format(b)}')
    
    if max_loss == -1:
      max_loss = loss.detach().numpy()
    sub2.plot(range(1, len(losses)+1), losses, '-o')
    plt.xticks(range(1, 7), xt)
    sub2.set_xlim([0.5, 6.5]); sub2.set_ylim([-2.5, max_loss+2.5])
    sub2.set_title(f'Losses (epoch {epoch+1} loss: {"{0:.4f}".format(loss)})')
    sub2.set_xlabel('epoch')
    print(f'Epoch: {epoch+1}, Loss = {loss.item(): .4f}, Model parameters = [w: {w}, b: {b}]')
    plt.show()
# Out:
# Epoch: 1, Loss =  69.3147, Model parameters = [w: -0.16852249205112457, b: -0.06496304273605347]
# Epoch: 2, Loss =  65.2818, Model parameters = [w: 1.2020279169082642, b: 0.1370449960231781]
# Epoch: 10, Loss =  29.1121, Model parameters = [w: 0.7294005751609802, b: 0.17005863785743713]
# Epoch: 100, Loss =  19.9437, Model parameters = [w: 0.6264693140983582, b: 0.8044965863227844]
# Epoch: 500, Loss =  12.0139, Model parameters = [w: 0.4766329824924469, b: 1.8825385570526123]
# Epoch: 1000, Loss =  9.2941, Model parameters = [w: 0.4395574629306793, b: 2.1620852947235107]

# %% [markdown]
# # References
# Congratulations! You have finished the introductory notebook.
# Some references to learn how to use basic python libraries (Numpy, Scipy and Matplotlib) that you would need for this course:
#
# [1] https://docs.python.org/3/tutorial/
#
# [2] http://cs231n.github.io/python-numpy-tutorial/
#
# [3] https://numpy.org/devdocs/user/quickstart.html
#
# [4] https://matplotlib.org/stable/tutorials/introductory/pyplot.html
#
# [5] https://pytorch.org/tutorials/beginner/basics/intro.html
